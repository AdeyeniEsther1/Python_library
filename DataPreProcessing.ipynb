# %% [markdown]
# ### Data Preprocessing
# # Instructions
#
# Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'.
# What is the data type of the 'client_0_bills' variable ?
# Display the general information of the dataset and try to answer the following questions :
# How many rows and columns do we have in this dataset ?
# How many categorical features are present in the dataset ?
# How much memory space does the dataset consume ?
# Inspect the dataset for potential missing values.
# Select your strategy to handle missing values, and tell us why you had made that choice.
# Run a descriptive analysis on numeric features (columns).
# Select the bills records for the client with an id ='train_Client_0', using 2 methods.
# Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
# Delete the 'counter_statue' feature from the Dataframe

# %%
import pandas as pd

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
#load the dataset
pd.read_csv("STEG_BILLING_HISTORY.csv")
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# 4476747  train_Client_99999   1996-05-28          11        560948.0
# 4476748  train_Client_99999   1996-01-25          11        560948.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
df=pd.read_csv("STEG_BILLING_HISTORY.csv")

# %%
#create a dataframe for the dataset
pd.DataFrame(df)
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# 4476747  train_Client_99999   1996-05-28          11        560948.0
# 4476748  train_Client_99999   1996-01-25          11        560948.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
#display the first 10 lines
df.head(10)
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
# 5  train_Client_0   2017-07-17          11       1335667.0              0
# 6  train_Client_0   2018-12-07          11       1335667.0              0
# 7  train_Client_0   2019-03-19          11       1335667.0              0
# 8  train_Client_0   2011-07-22          11       1335667.0              0
# 9  train_Client_0   2011-11-22          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
#store the result in a variable called 'client_0_bills'
client_0_bills = df.head(10)

# %%
#datatype of client_0_bills
client_0_bills.dtypes
# Out:
# client_id                object
# invoice_date             object
# tarif_type                int64
# counter_number          float64
# counter_statue           object
# counter_code              int64
# reading_remarque        float64
# counter_coefficient       int64
# consommation_level_1      int64
# consommation_level_2      int64
# consommation_level_3      int64
# consommation_level_4      int64
# old_index                 int64
# new_index                 int64
# months_number             int64
# counter_type             object
# dtype: object

# %%
#display the general informationof the dataset
#Total number of rows and columns each in the dataset
#total number of rows in the dataset
num_of_rows= len(df)
print(f"The dataset has {num_of_rows} rows.")
#total number of columns in the dataset
num_of_columns= len(df.columns)
print(f"The dataset has {num_of_columns} columns.")
# Out:
# The dataset has 4476749 rows.
# The dataset has 16 columns.

# %%
#another way to check the total number of rows and total no of columns
df.shape
# Out:
# (4476749, 16)

# %%
#the amount of categorical features in the dataset
#select categorical columns
categorical_features = df.select_dtypes(include='category')
# Count the number of categorical features
num_categorical_features = len(categorical_features.columns)
print(f"The dataset has {num_categorical_features} categorical features.")
# Out:
# The dataset has 0 categorical features.

# %%
#how much memory space does the dataset have
df.memory_usage
# Out:
# <bound method DataFrame.memory_usage of                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# 4476747  train_Client_99999   1996-05-28          11        560948.0
# 4476748  train_Client_99999   1996-01-25          11        560948.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
#inspect the dataset for potential missing vales
total_missing = df.isnull().sum().sum()

print(f"There are a total of {total_missing} missing values in the dataset.")
# Out:
# There are a total of 4579 missing values in the dataset.

# %%
#handling the missing values(will replace them with zero)
df_filled = df.fillna(0)  # Replace with 0

# %% [markdown]
# #Select your strategy to handle missing values, and tell us why you had made that choice.
#
# ## STRATEGY TO HANDLE MISSING VALUES
# The strategy to handle the missing values in this dataset is to drop missing values or fill the missing values with zero,in which I did.
# The dropping of missing values will automotaically remove rows and colums containing missing values entirely.
# Meanwhile, the approach I used with this dataset was filling the values with 0.In this case, all missing values will be replaced with 0.
# # Why I made this choice?
# - Simplicity: Replacing missing values with zero is a straightforward and easy-to-implement method. It doesn't require complex calculations or advanced statistical techniques.
# - Preserves Data Structure: Unlike dropping rows or columns, replacing with zero maintains the original structure of the DataFrame, which can be helpful for some analyses, especially if the number of missing values is small.
# - Certain Scenarios: In specific cases, missing values might genuinely represent a zero value. For example, if a column tracks "number of purchases," a missing value could represent a customer who didn't buy anything (resulting in a zero value).

# %%
#Run a descriptive analysis on numeric features (columns).
df.describe()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  4.476749e+06    4.476701e+06  4.476749e+06      4.472218e+06
# mean   2.012804e+01    1.230595e+11  1.724884e+02      7.321713e+00
# std    1.347256e+01    1.657276e+12  1.338871e+02      1.571859e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      5.000000e+00
# 25%    1.100000e+01    1.211080e+05  5.000000e+00      6.000000e+00
# 50%    1.100000e+01    4.945610e+05  2.030000e+02      8.000000e+00
# 75%    4.000000e+01    1.115161e+06  2.070000e+02      9.000000e+00
# max    4.500000e+01    2.798115e+13  6.000000e+02      4.130000e+02
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         4.476749e+06          4.476749e+06          4.476749e+06
# mean          1.003040e+00          4.109795e+02          1.093225e+02
# std           3.083466e-01          7.573080e+02          1.220123e+03
# ...

# %%
# Select the bills records for the client with an id ='train_Client_0', using 2 methods.
# first method
df[df.client_id == "train_Client_0"]
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
#second method
df.query("client_id == 'train_Client_0'")
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
#Transform the 'counter_type' feature to a numeric variable using the encoder of your choice
#import the labelEncoder from the scikit-learn library
from sklearn.preprocessing import LabelEncoder
#Create a labelEncoder object
encoder = LabelEncoder()
# Fit the encoder to the 'counter_type' feature
encoder.fit(df['counter_type'])
# Transform the 'counter_type' feature (categorical to numerical)
df['counter_type_encoded'] = encoder.transform(df['counter_type'])

# %%
df.head(3)
#this is a sample that result shows the changes after transforming the "counter_type" feature.
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                    1                    82
# 1           203               6.0                    1                  1200
# 2           203               8.0                    1                   123
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
#
#    old_index  new_index  months_number counter_type  counter_type_encoded
# ...

# %%
#Delete the 'counter_statue' feature from the Dataframe
df.drop("counter_statue", axis=1)
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# 4476747  train_Client_99999   1996-05-28          11        560948.0
# 4476748  train_Client_99999   1996-01-25          11        560948.0
#
#          counter_code  reading_remarque  counter_coefficient  \
# 0                 203               8.0                    1
# ...
